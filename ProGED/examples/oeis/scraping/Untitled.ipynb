# %%
import pandas as pd
csv_filename = "oeis_dmkd.csv"
check = pd.read_csv(csv_filename)

# %%
print(check)
# Out:
#                                                 A000001  \
# 0     Number of groups of order n.\n                ...
# 1                                                     0
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 996                                                   1
# 997                                                  10
# 998                                                   1
# 999                                                   2
# 1000                                                 15
#
#                                                 A000002  \
# 0     Kolakoski sequence: a(n) is length of n-th run...
# 1                                                     1
# 2                                                     2
# 3                                                     2
# ...

# %%
ls
# Out:
# /home/bosg/Documents/py-envs/edvenv/bin/python
